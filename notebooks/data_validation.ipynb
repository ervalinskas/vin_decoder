# %%
import pandas as pd

# %% [markdown]
# ##### Checking if there are conflicting `make`, `model`, `year` and `body` assigned to the same VIN (VIN without the serial number part)

# %%
# Dropping serial numbers from VINs since they are redacted and serve no purpose
df = pd.read_csv("../data/raw/ml-engineer-challenge-redacted-data.csv")
df = df.drop_duplicates()
df = df.sort_values(by="vin")
df
# Out:
#                     vin  make     model    year       body
# 1882  3MW5R1J0XM8CXXXXX   BMW  3 Series  2021.0        NaN
# 2930  4USBT33443LRXXXXX   BMW        Z4  2003.0        NaN
# 1622  5UXCR4C06M9FXXXXX   BMW        X5  2021.0        NaN
# 2211  5UXCY6C04P9PXXXXX   BMW       NaN     NaN        NaN
# 2210  5UXCY6C04P9PXXXXX   BMW        X6  2023.0        SUV
# ...                 ...   ...       ...     ...        ...
# 2109  WUAZZZFX9J79XXXXX  Audi        R8  2018.0        NaN
# 2115  WUAZZZFX9J79XXXXX  Audi        R8     NaN        NaN
# 2112  WUAZZZFX9J79XXXXX  Audi        R8     NaN  crossover
# 1059  WUAZZZGY4NA9XXXXX  Audi       NaN     NaN        NaN
# 191   X4XKT294100YXXXXX   BMW  X Series     NaN        SUV
#
# [2275 rows x 5 columns]

# %%
from pandas import DataFrame
from typing import Callable, List

def check_for_conflicts(df: DataFrame, col: str, gr_col: str = "vin") -> DataFrame:
    vin_col_df = df[[gr_col, col]].copy().drop_duplicates()
    non_null_vin_col_df = vin_col_df[vin_col_df[col].notnull()]
    non_null_vin_col_grouped = non_null_vin_col_df.groupby(gr_col)
    non_null_vin_col_conflicts = non_null_vin_col_grouped.filter(lambda x: x[col].nunique() > 1)
    print("There are no conflicts!") if non_null_vin_col_conflicts.empty else print("Conflicts found!")
    return non_null_vin_col_grouped


def get_conflicting_vins(df: DataFrame, col: str, func_list: List[Callable | str] = [set, 'count']) -> DataFrame:
    result = df.agg(func_list).rename(columns={"shortened_vin": "count"})
    result.columns = result.columns.to_flat_index().str.join("_")
    result = result[result[col + "_count"] > 1].drop(columns=[col + "_count"])
    return result.reset_index()


def display_df(df: DataFrame) -> None:
    with pd.option_context("display.max_rows", None,"display.max_columns", None):
        display(df)

# %% [markdown]
# ##### Checking if there are conflicting make values

# %%
col = "make"
vin_make_conflicts_df = check_for_conflicts(df=df, col=col)
# Out:
# There are no conflicts!

# %% [markdown]
# ##### Checking if there are conflicting models

# %%
col = "model"
vin_model_conflicts_df = check_for_conflicts(df=df, col=col)
# Out:
# Conflicts found!

# %% [markdown]
# These VINs should be flagged for human inspection and until then should not be included into the training of the vehicle model classifier!

# %%
conflicting_models_df = get_conflicting_vins(df=vin_model_conflicts_df, col=col)
display_df(conflicting_models_df)
# Out:
#                    vin                  model_set
# 0    5UXFE43568L0XXXXX             {X5, X Series}
# 1    5UXFG43578L2XXXXX             {X6, X Series}
# 2    5UXTS3C57K0ZXXXXX             {X3, X Series}
# 3    WA1B4AFY6L20XXXXX                  {SQ5, Q5}
# 4    WAURV68T59A0XXXXX                   {A5, S5}
# 5    WAUZZZ44ZJN2XXXXX                  {A6, 100}
# 6    WAUZZZ4G1EN1XXXXX          {A6, A7, allroad}
# 7    WAUZZZ4G9DN0XXXXX                   {A6, A7}
# 8    WAUZZZ4GXHN1XXXXX                   {A6, A7}
# 9    WAUZZZ8V2DA0XXXXX                   {A4, A3}
# 10   WBA3N3C50EK2XXXXX     {428I (USA), 4 Series}
# 11   WBA3N9C51GK2XXXXX              {4, 4 Series}
# 12   WBA3R5C55FK3XXXXX              {4, 4 Series}
# 13   WBA3U510505CXXXXX              {4, 4 Series}
# 14   WBA4B1C57FG2XXXXX              {4, 4 Series}
# 15   WBA4C31030G0XXXXX              {4, 4 Series}
# 16   WBA4E910X0G7XXXXX              {4, 4 Series}
# 17   WBA4F11020D9XXXXX              {4, 4 Series}
# 18   WBA4J5C5XKBMXXXXX              {4, 4 Series}
# 19   WBA4K51090BHXXXXX              {4, 4 Series}
# 20   WBA4W7C57JABXXXXX              {4, 4 Series}
# 21   WBA4X51020ABXXXXX              {4, 4 Series}
# 22   WBA4X910X0AEXXXXX              {4, 4 Series}
# 23   WBA5D11060D7XXXXX              {5 Series, R}
# 24   WBA6A81020D8XXXXX  {6 Series, 640dx (640dx)}
# 25   WBA6E41090G3XXXXX  {6 Series, 640dx (640dx)}
# 26   WBA8J11020K6XXXXX              {R, 3 Series}
# 27   WBACV610X09BXXXXX             {2 Series, X5}
# 28   WBAFB31000LGXXXXX             {X5, X Series}
# 29   WBAFB51010LUXXXXX             {X5, X Series}
# 30   WBAFB71060LXXXXXX             {X5, X Series}
# 31   WBAFB71070LXXXXXX             {X5, X Series}
# 32   WBAFB71080LVXXXXX             {X5, X Series}
# 33   WBAFB710X0LXXXXXX             {X5, X Series}
# 34   WBAFF01020L2XXXXX             {X5, X Series}
# 35   WBAFF41030L0XXXXX             {X5, X Series}
# 36   WBAFF41060L1XXXXX             {X5, X Series}
# 37   WBAFF41090L1XXXXX             {X5, X Series}
# 38   WBAFH61000L4XXXXX             {X6, X Series}
# 39   WBAFH610300BXXXXX             {X6, X Series}
# 40   WBAFR7C58CC8XXXXX             {5 Series, i3}
# 41   WBAHE21050GEXXXXX              {5 Series, R}
# 42   WBAJF51050WWXXXXX              {5 Series, R}
# 43   WBAJW81040BEXXXXX        {Z4, 630dx (630dx)}
# 44   WBAKM81070CYXXXXX       {5 Series, 7 Series}
# 45   WBAKS210300HXXXXX             {X5, X Series}
# 46   WBAKS410400RXXXXX             {X5, X Series}
# 47   WBAKS4108H0RXXXXX             {X5, X Series}
# 48   WBAKS810100MXXXXX             {X5, X Series}
# 49   WBAKS810600MXXXXX             {X5, X Series}
# 50   WBAKV210200VXXXXX             {X6, X Series}
# 51   WBAKV610300WXXXXX             {X6, X Series}
# 52   WBAKV610X00NXXXXX             {X6, X Series}
# 53   WBALS010000SXXXXX             {X5, X Series}
# 54   WBANC71000B6XXXXX              {G, 5 Series}
# 55   WBANX71090CSXXXXX           {530D, 5 Series}
# 56   WBAPB51010WBXXXXX             {X3, X Series}
# 57   WBAPD11000WFXXXXX             {X Series, X3}
# 58   WBAPD71020WFXXXXX             {X Series, X3}
# 59   WBAPD71060WFXXXXX             {X Series, X3}
# 60   WBAPE11070WJXXXXX             {X Series, X3}
# 61   WBAPE11080WJXXXXX             {X3, X Series}
# 62   WBAPE11090WJXXXXX             {X3, X Series}
# 63   WBAPY71080C0XXXXX              {5 Series, R}
# 64   WBASP61080C3XXXXX             {Z4, 5 Series}
# 65   WBATR51080LAXXXXX             {X Series, X3}
# 66   WBATS31070LFXXXXX             {X Series, X3}
# 67   WBATX15060NAXXXXX             {X Series, X3}
# 68   WBATX31020LCXXXXX             {X Series, X3}
# 69   WBATX31030LCXXXXX             {X3, X Series}
# 70   WBATX31090LCXXXXX             {X3, X Series}
# 71   WBATX35000NCXXXXX             {X3, X Series}
# 72   WBATX3503KNEXXXXX             {X Series, X3}
# 73   WBATX71010LBXXXXX             {X3, X Series}
# 74   WBAVC91030KSXXXXX              {R, 3 Series}
# 75   WBAVM1C58EVWXXXXX             {X1, X Series}
# 76   WBAVP31030VKXXXXX             {X1, X Series}
# 77   WBAWD710X0P0XXXXX       {5 Series, 3 Series}
# 78   WBAWX31060L9XXXXX             {X Series, X3}
# 79   WBAWY110300CXXXXX             {X3, X Series}
# 80   WBAWY31040L5XXXXX             {X3, X Series}
# 81   WBAWY310700AXXXXX             {X Series, X3}
# 82   WBAWY31080L6XXXXX             {X3, X Series}
# 83   WBAWY310900AXXXXX             {X3, X Series}
# 84   WBAWY510X00EXXXXX             {X Series, X3}
# 85   WBAWZ510X00YXXXXX             {X3, X Series}
# 86   WBAXX110800TXXXXX             {X Series, X4}
# 87   WBAYH31040EPXXXXX             {X2, X Series}
# 88   WBAZW61050L5XXXXX             {X5, X Series}
# 89   WBS3R91010K4XXXXX              {4, 4 Series}
# 90   WBS3R91060K3XXXXX              {4, 4 Series}
# 91   WBS3R9C50FF7XXXXX              {4, 4 Series}
# 92   WBS3R9C56FK3XXXXX              {4, 4 Series}
# 93   WBS4Y91080ACXXXXX              {4, 4 Series}
# 94   WBS4Y9C54KAGXXXXX              {4, 4 Series}
# 95   WBSGY01060LKXXXXX             {X5, X Series}
# 96   WBSKT610600RXXXXX             {X5, X Series}
# 97   WBSNB91040CXXXXXX             {M5, 5 Series}
# 98   WBY1Z610007AXXXXX                    {i3, i}
# 99   WBY1Z610XHV9XXXXX                    {i3, i}
# 100  WBY2Z21040V3XXXXX                    {i8, i}
# 101  WBY7Z61080VGXXXXX                    {i3, i}
# 102  WBY8P6105K7DXXXXX                    {i3, i}
# 103  WUAZZZ8P6C19XXXXX                 {A3, rs 7}
# 104  WUAZZZ8T1BA9XXXXX                   {A5, 80}

# %% [markdown]
# Splitting the whole dataset into good and bad records. Bad records are the ones that requires human intervention. We'll use records only from files with `_good.csv` suffix.

# %%
vin_model_pairs_good = df[~df["vin"].isin(conflicting_models_df.vin)]
vin_model_pairs_good.to_csv("../data/data_validation/vin_model_pairs_good.csv", index=False, header=True)

# %%
vin_model_pairs_bad = df[df["vin"].isin(conflicting_models_df.vin)]
vin_model_pairs_bad.to_csv("../data/data_validation/vin_model_pairs_bad.csv", index=False, header=True)

# %% [markdown]
# ##### Checking if there are conflicting year values

# %%
col = "year"
vin_year_conflicts_df = check_for_conflicts(df=df, col=col)
# Out:
# Conflicts found!

# %% [markdown]
# These VINs should be flagged for human inspection and until then should not be included into the training of the vehicle year classifier!

# %%
conflicting_year_df = get_conflicting_vins(df=vin_year_conflicts_df, col=col)
display_df(conflicting_year_df)
# Out:
#                  vin          year_set
# 0  WAUZZZ4G4GN0XXXXX  {2016.0, 2015.0}
# 1  WAUZZZ8U6ER1XXXXX  {2014.0, 2015.0}

# %% [markdown]
# Splitting the whole dataset into good and bad records. Bad records are the ones that requires human intervention. We'll use records only from files with `_good.csv` suffix.

# %%
vin_year_pairs_good = df[~df["vin"].isin(conflicting_year_df.vin)]
vin_year_pairs_good.to_csv("../data/data_validation/vin_year_pairs_good.csv", index=False, header=True)

# %%
vin_year_pairs_bad = df[df["vin"].isin(conflicting_year_df.vin)]
vin_year_pairs_bad.to_csv("../data/data_validation/vin_year_pairs_bad.csv", index=False, header=True)

# %% [markdown]
# ##### Checking if there are conflicting body values

# %%
col = "body"
vin_body_conflicts_df = check_for_conflicts(df=df, col=col)
# Out:
# Conflicts found!

# %% [markdown]
# These VINs should be flagged for human inspection and until then should not be included into the training of the vehicle body set classifier!

# %%
conflicting_body_df = get_conflicting_vins(df=vin_body_conflicts_df, col=col)
display_df(conflicting_body_df)
# Out:
#                   vin                         body_set
# 0   WA1LFAFP3FA0XXXXX     {multi-purpose vehicle, SUV}
# 1   WAUZZZ4F17N0XXXXX                  {estate, sedan}
# 2   WAUZZZ4G1EN1XXXXX              {estate, hatchback}
# 3   WAUZZZ4G9HN0XXXXX                    {van, estate}
# 4   WAUZZZ4L98D0XXXXX                       {van, SUV}
# 5   WAUZZZ4M1JD0XXXXX                       {van, SUV}
# 6   WAUZZZ4M3GD0XXXXX                 {crossover, SUV}
# 7   WAUZZZ4M3KD0XXXXX                       {van, SUV}
# 8   WAUZZZ8K4DA2XXXXX                    {estate, SUV}
# 9   WAUZZZ8K9DA1XXXXX              {estate, hatchback}
# 10  WAUZZZ8R0BA1XXXXX                       {van, SUV}
# 11  WAUZZZ8R0EA0XXXXX                    {estate, SUV}
# 12  WAUZZZ8R7EA1XXXXX                 {crossover, SUV}
# 13  WAUZZZ8T6GA0XXXXX               {hatchback, sedan}
# 14  WAUZZZ8T89A0XXXXX               {crossover, coupe}
# 15  WAUZZZ8U2JR0XXXXX                    {estate, SUV}
# 16  WAUZZZ8U3ER1XXXXX                    {estate, SUV}
# 17  WAUZZZF27KN0XXXXX                  {estate, sedan}
# 18  WAUZZZF34L10XXXXX                    {estate, SUV}
# 19  WAUZZZF37K10XXXXX                       {van, SUV}
# 20  WBA1C11050VSXXXXX              {estate, hatchback}
# 21  WBA1S51040V9XXXXX              {estate, hatchback}
# 22  WBA2D710105CXXXXX     {van, multi-purpose vehicle}
# 23  WBA2E11090P9XXXXX  {multi-purpose vehicle, estate}
# 24  WBA3Y3101ED6XXXXX               {hatchback, sedan}
# 25  WBA4B1C57FG2XXXXX                {sedan, liftback}
# 26  WBA4C31030G0XXXXX            {hatchback, liftback}
# 27  WBA4J5C5XKBMXXXXX                {sedan, liftback}
# 28  WBA4K51090BHXXXXX                {sedan, liftback}
# 29  WBA5N61040D9XXXXX               {hatchback, sedan}
# 30  WBA6T910307DXXXXX  {multi-purpose vehicle, estate}
# 31  WBA8D11070K4XXXXX               {hatchback, sedan}
# 32  WBA8J11020K6XXXXX                    {van, estate}
# 33  WBAAA3100095XXXXX                   {coupe, sedan}
# 34  WBACR62020LSXXXXX                    {estate, SUV}
# 35  WBACV610X09BXXXXX                       {van, SUV}
# 36  WBAFB71030LWXXXXX                 {crossover, SUV}
# 37  WBAKV210200VXXXXX                     {SUV, sedan}
# 38  WBAKV610X00NXXXXX                    {estate, SUV}
# 39  WBAMX11010DYXXXXX                  {estate, sedan}
# 40  WBAPD71060WFXXXXX                     {SUV, sedan}
# 41  WBAPX51020C1XXXXX                    {estate, SUV}
# 42  WBAPX51090CUXXXXX                    {estate, SUV}
# 43  WBAPX71090B9XXXXX                    {estate, SUV}
# 44  WBATX15060NAXXXXX                       {van, SUV}
# 45  WBAUY11090A9XXXXX                  {estate, sedan}
# 46  WBAUY110X0F0XXXXX                    {estate, SUV}
# 47  WBAVU51010A1XXXXX                    {van, estate}
# 48  WBAXX110800TXXXXX                 {crossover, SUV}
# 49  WBAYH32030EHXXXXX                 {SUV, hatchback}
# 50  WBS3R9C50FF7XXXXX               {crossover, coupe}
# 51  WBXHT3C3XG5EXXXXX                 {crossover, SUV}
# 52  WBY1Z610007AXXXXX                 {van, hatchback}

# %% [markdown]
# Splitting the whole dataset into good and bad records. Bad records are the ones that requires human intervention. We'll use records only from files with `_good.csv` suffix.

# %%
vin_body_pairs_good = df[~df["vin"].isin(conflicting_body_df.vin)]
vin_body_pairs_good.to_csv("../data/data_validation/vin_body_pairs_good.csv", index=False, header=True)

# %%
vin_body_pairs_bad = df[df["vin"].isin(conflicting_body_df.vin)]
vin_body_pairs_bad.to_csv("../data/data_validation/vin_body_pairs_bad.csv", index=False, header=True)
